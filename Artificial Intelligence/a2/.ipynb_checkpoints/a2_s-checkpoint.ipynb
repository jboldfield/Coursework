# %% [markdown]
# # CS 4820
# # Assignment 2
# ## Due: ...

# %% [markdown]
# ### Problem 1
#
# The followig function encapsulates the code that calculates the decision boundary and is called `plot_decision_boundary` with the signature:
#
# ```python
# def plot_decision_boundary(model, X, y):
#     ....
# ```

# %%
import numpy as np

# allow multiple outputs be displayed for each cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import matplotlib.pyplot as plt

def plot_decision_boundary(model, X, y):
    hticks = np.linspace(X.min()-0.1, X.max()+0.1, 101)
    vticks = np.linspace(X.min()-0.1, X.max()+0.1, 101)
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    
    c = model.predict(ab)
    cc = c.reshape(aa.shape)
    
    plt.figure(figsize=(7, 7))
    plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
    plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
    plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
    plt.title("Blue circles and Red crosses");

# %% [markdown]
# 1.1 Practice retraining the model on different data:
#
# - use the function `make_blobs` from `sklearn.datasets` to generate a new dataset
# - plot the new dataset to make sure you understand it
#
# ![make_blobs.png](./assets/make_blobs.png)
#
# - re-train your model on this dataset
# - display the decision boundary for each of this model
#
# ![decision_boundary_blobs.png](./assets/decision_boundary_blobs.png)

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=1000,
                  centers=2,
                  random_state=0)

plt.figure(figsize=(7, 7))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses created by make_blobs");

# plt.savefig("make_blobs.png")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

model = Sequential()
model.add(Dense(4, input_shape=(2,), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer=SGD(lr=0.5),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(X, y, epochs=20);
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.2948 - accuracy: 0.9240
# Epoch 2/20
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.1857 - accuracy: 0.9370
# Epoch 3/20
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.1708 - accuracy: 0.9350
# Epoch 4/20
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.1527 - accuracy: 0.9410
# Epoch 5/20
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1370 - accuracy: 0.9530
# Epoch 6/20
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.1520 - accuracy: 0.9400
# Epoch 7/20
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.1266 - accuracy: 0.9500
# Epoch 8/20
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.1382 - accuracy: 0.9510
# Epoch 9/20
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.1223 - accuracy: 0.9530
# Epoch 10/20
# 1000/1000 [==============================] - 0s 36us/sample - loss: 0.1419 - accuracy: 0.9420
# Epoch 11/20
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1446 - accuracy: 0.9400
# Epoch 12/20
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.1410 - accuracy: 0.9440
# Epoch 13/20
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.1300 - accuracy: 0.9450
# Epoch 14/20
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1228 - accuracy: 0.9480
# Epoch 15/20
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.1293 - accuracy: 0.9470
# Epoch 16/20
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1156 - accuracy: 0.9560
# Epoch 17/20
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.1180 - accuracy: 0.9540
# Epoch 18/20
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.1236 - accuracy: 0.9460
# Epoch 19/20
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.1123 - accuracy: 0.9600
# Epoch 20/20
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.1201 - accuracy: 0.9520

# %%
plot_decision_boundary(model, X, y)

# plt.savefig("decision_boundary_blobs.png")

# %% [markdown]
# 1.2 Another practice retraining the model on different data:
#
# - use the function `make_moons` from `sklearn.datasets` to generate a new dataset
# - plot the new dataset to make sure you understand it
#
# ![make_moons.png](./assets/make_moons.png)
#
# - re-train your model on this dataset
# - display the decision boundary for each of this model
#
# ![decision_boundary_moons.png](./assets/decision_boundary_moons.png)

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=1000,
                  noise=0.1,
                  random_state=0)

plt.figure(figsize=(7, 7))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses created by make_moons");

# plt.savefig("make_moons.png")

# %%
model = Sequential()
model.add(Dense(4, input_shape=(2,), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer=SGD(lr=0.5),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(X, y, epochs=50);
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 0s 110us/sample - loss: 0.3926 - accuracy: 0.8010
# Epoch 2/50
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.2809 - accuracy: 0.8720
# Epoch 3/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.2661 - accuracy: 0.8750
# Epoch 4/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2653 - accuracy: 0.8730
# Epoch 5/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2617 - accuracy: 0.8790
# Epoch 6/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.2628 - accuracy: 0.8780
# Epoch 7/50
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2625 - accuracy: 0.8740
# Epoch 8/50
# 1000/1000 [==============================] - 0s 36us/sample - loss: 0.2594 - accuracy: 0.8780
# Epoch 9/50
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.2644 - accuracy: 0.8750
# Epoch 10/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.2658 - accuracy: 0.8710
# Epoch 11/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.2664 - accuracy: 0.8740
# Epoch 12/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.2649 - accuracy: 0.8710
# Epoch 13/50
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.2655 - accuracy: 0.8790
# Epoch 14/50
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.2620 - accuracy: 0.8750
# Epoch 15/50
# 1000/1000 [==============================] - 0s 37us/sample - loss: 0.2647 - accuracy: 0.8710
# Epoch 16/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.2638 - accuracy: 0.8720
# Epoch 17/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.2605 - accuracy: 0.8830
# Epoch 18/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.2616 - accuracy: 0.8780
# Epoch 19/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2622 - accuracy: 0.8690
# Epoch 20/50
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.2684 - accuracy: 0.8700
# Epoch 21/50
# 1000/1000 [==============================] - 0s 37us/sample - loss: 0.2601 - accuracy: 0.8760
# Epoch 22/50
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.2611 - accuracy: 0.8810
# Epoch 23/50
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.2598 - accuracy: 0.8730
# Epoch 24/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2577 - accuracy: 0.8760
# Epoch 25/50
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.2638 - accuracy: 0.8740
# Epoch 26/50
# 1000/1000 [==============================] - 0s 41us/sample - loss: 0.2624 - accuracy: 0.8760
# Epoch 27/50
# 1000/1000 [==============================] - 0s 48us/sample - loss: 0.2597 - accuracy: 0.8760
# Epoch 28/50
# 1000/1000 [==============================] - 0s 52us/sample - loss: 0.2607 - accuracy: 0.8780
# Epoch 29/50
# 1000/1000 [==============================] - 0s 36us/sample - loss: 0.2600 - accuracy: 0.8740
# Epoch 30/50
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.2621 - accuracy: 0.8690
# Epoch 31/50
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.2584 - accuracy: 0.8760
# Epoch 32/50
# 1000/1000 [==============================] - 0s 38us/sample - loss: 0.2596 - accuracy: 0.8790
# Epoch 33/50
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.2592 - accuracy: 0.8730
# Epoch 34/50
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.2596 - accuracy: 0.8730
# Epoch 35/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.2646 - accuracy: 0.8700
# Epoch 36/50
# 1000/1000 [==============================] - 0s 36us/sample - loss: 0.2594 - accuracy: 0.8840
# Epoch 37/50
# 1000/1000 [==============================] - 0s 36us/sample - loss: 0.2589 - accuracy: 0.8740
# Epoch 38/50
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.2599 - accuracy: 0.8740
# Epoch 39/50
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.2565 - accuracy: 0.8790
# Epoch 40/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2556 - accuracy: 0.8780
# Epoch 41/50
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.2577 - accuracy: 0.8740
# Epoch 42/50
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.2530 - accuracy: 0.8740
# Epoch 43/50
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.2513 - accuracy: 0.8750
# Epoch 44/50
# 1000/1000 [==============================] - 0s 40us/sample - loss: 0.2481 - accuracy: 0.8800
# Epoch 45/50
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.2468 - accuracy: 0.8790
# Epoch 46/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.2418 - accuracy: 0.8840
# Epoch 47/50
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2243 - accuracy: 0.9000
# Epoch 48/50
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.1999 - accuracy: 0.9090
# Epoch 49/50
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1665 - accuracy: 0.9390
# Epoch 50/50
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.1314 - accuracy: 0.9600

# %%
plot_decision_boundary(model, X, y)

# plt.savefig("decision_boundary_moons.png")
