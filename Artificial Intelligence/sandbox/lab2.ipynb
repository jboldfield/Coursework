# %% [markdown]
# # CS 4820
# # Lab 2: Multi-layer Neural Networks

# %% [markdown]
# ### 1. Logic XOR
#
# As we all know, a Perceptron is not capable of learning **logical XOR** since it's not linearly separable. Now let's build a multi-layer NN to learn it.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# the four different states of the logical XOR operation
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# the four expected results in the same order
target_data = np.array([[0],[1],[1],[0]], "float32")

print(target_data)

model = Sequential()

model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

model.fit(training_data, target_data, epochs=500, verbose=2, batch_size=4)

print(model.layers[0].get_weights())
print('**********')
print(model.layers[1].get_weights())

print("Test results:\n:", model.predict(training_data))
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Epoch 1/500
# 4/4 - 0s - loss: 0.2374 - binary_accuracy: 0.7500
# Epoch 2/500
# 4/4 - 0s - loss: 0.2370 - binary_accuracy: 0.5000
# Epoch 3/500
# 4/4 - 0s - loss: 0.2366 - binary_accuracy: 0.5000
# Epoch 4/500
# 4/4 - 0s - loss: 0.2362 - binary_accuracy: 0.5000
# Epoch 5/500
# 4/4 - 0s - loss: 0.2359 - binary_accuracy: 0.5000
# Epoch 6/500
# 4/4 - 0s - loss: 0.2355 - binary_accuracy: 0.5000
# Epoch 7/500
# 4/4 - 0s - loss: 0.2351 - binary_accuracy: 0.5000
# Epoch 8/500
# 4/4 - 0s - loss: 0.2348 - binary_accuracy: 0.5000
# Epoch 9/500
# 4/4 - 0s - loss: 0.2344 - binary_accuracy: 0.5000
# Epoch 10/500
# 4/4 - 0s - loss: 0.2341 - binary_accuracy: 0.5000
# Epoch 11/500
# 4/4 - 0s - loss: 0.2337 - binary_accuracy: 0.5000
# Epoch 12/500
# 4/4 - 0s - loss: 0.2334 - binary_accuracy: 0.5000
# Epoch 13/500
# 4/4 - 0s - loss: 0.2330 - binary_accuracy: 0.5000
# Epoch 14/500
# 4/4 - 0s - loss: 0.2327 - binary_accuracy: 0.5000
# Epoch 15/500
# ...

# %% [markdown]
# ### 2. What to submit?
#
# For this lab, please complete and submit this jupyter notebook named _lab2.ipynb_.
