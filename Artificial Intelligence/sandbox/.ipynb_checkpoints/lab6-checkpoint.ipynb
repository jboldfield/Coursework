# %% [markdown]
# # CS 4820
# # Lab 6: Convolving a Gray Scale Image

# %% [markdown]
# ### Load a Gray Scale Image

# %%
# allow multiple outputs be displayed for each cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# First of all, let's load an example gray scale image from [`scipy.misc`](https://docs.scipy.org/doc/scipy/reference/misc.html):

# %%
from scipy import misc
import matplotlib.pyplot as plt

# %%
img = misc.ascent()

plt.figure(figsize=(7,7))
plt.imshow(img, cmap='gray')

# %%
print(img.shape)

img_tensor = img.reshape((1,512,512,1))
# Out:
# (512, 512)

# %% [markdown]
# $(N, H, W, C) = (1, 512, 512, 1)$

# %% [markdown]
# ### One convolutional Layer
#
# Convolutional layers are available in [`keras.layers.Conv2D`](https://keras.io/layers/convolutional/). Let's apply a convolutional layer to the image we loaded above and see what happens.
#
# First, let's import the `Conv2D` layer from keras:

# %%
from tensorflow.keras.layers import Conv2D

# %% [markdown]
# $(H_f, W_f, C_i, C_o) = (11, 11 , 1, 1)$

# %%
from tensorflow.keras.models import Sequential

model = Sequential()

model.add(Conv2D(1, (11, 11), kernel_initializer='ones', input_shape=(512, 512, 1)))

model.compile('adam', 'mse')

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 502, 502, 1)       122
# =================================================================
# Total params: 122
# Trainable params: 122
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Q: Why output shape = (None, 502, 502, 1)?__
#
# A:
#
# - None is the numeber of output images (N).
# - 502 by 502 is the size of the output feature map.
# - Will be further explained after discussing padding and stride.
# - 1 is the number of output channels.
#
#
# $$ Param \# = Weight \# + Theta \# = H_f * W_f * C_o * C_i + C_o = 11 * 11 * 1 * 1 + 1 = 122 $$

# %%
img_pred_tensor = model.predict(img_tensor)

img_pred_tensor.shape
# Out:
# (1, 502, 502, 1)

# %%
img_pred = img_pred_tensor[0, :, :, 0]

fig, ax = plt.subplots(1, 2, figsize=(15, 15))
ax[0].imshow(img, cmap='gray'), ax[0].axis('off'), ax[0].set_title('Original Image ')
ax[1].imshow(img_pred, cmap='gray'), ax[1].axis('off'), ax[1].set_title('Predicted Image')
# Out:
# (<matplotlib.image.AxesImage at 0x1c4907ac248>,
#  (-0.5, 511.5, 511.5, -0.5),
#  Text(0.5, 1.0, 'Original Image '))
# (<matplotlib.image.AxesImage at 0x1c490802dc8>,
#  (-0.5, 501.5, 501.5, -0.5),
#  Text(0.5, 1.0, 'Predicted Image'))

# %% [markdown]
# ### Stacking Multiple Convolutional Layers

# %% [markdown]
# We can stack multiple convolutional layers to extract features from the original image that are not necessarily straight-forward for us human beings to comprehend/interpret.

# %%
model_2 = Sequential()

model_2.add(Conv2D(1, (11, 11), kernel_initializer='RandomNormal', input_shape=(512, 512, 1), activation='relu'))
# Conv2D(# of Filters, (size), kernel_initializers, INPUT IS GOTTEN BY KEAR, activation)
model_2.add(Conv2D(4, (5, 5), kernel_initializer='RandomNormal', activation='relu'))
model_2.add(Conv2D(2, (3, 3), kernel_initializer='RandomNormal', activation='relu'))

model_2.compile('adam', 'mse')

model_2.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 502, 502, 1)       122
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 498, 498, 4)       104
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 496, 496, 2)       74
# =================================================================
# Total params: 300
# Trainable params: 300
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Q: Why output shape = (None, 498, 498, 4) from the second conv. layer?__
#
# A:
#
# - None is the numeber of output images (N).
# - 498 by 498 is the size of the output feature map.
# - Will be further explained after discussing padding and stride.
# - 4 is the number of output channels.
#
#
# $$ Param \# = Weight \# + Theta \# = H_f * W_f * C_o * C_i + C_o = 5 * 5 * 4 * 1 + 4 = 104 $$
#
# __Q: Why output shape = (None, 496, 496, 2) from the third conv. layer?__
#
# A:
#
# - None is the numeber of output images (N).
# - 496 by 496 is the size of the output feature map.
# - Will be further explained after discussing padding and stride.
# - 2 is the number of output channels.
#
#
# $$ Param \# = Weight \# + Theta \# = H_f * W_f * C_o * C_i + C_o = 3 * 3 * 2 * 4 + 2 = 74 $$

# %%
img_pred_tensor_2 = model_2.predict(img_tensor)

img_pred_tensor_2.shape
# Out:
# (1, 496, 496, 2)

# %%
img_pred_1 = img_pred_tensor_2[0, :, :, 0]
img_pred_2 = img_pred_tensor_2[0, :, :, 1]

fig, ax = plt.subplots(1, 3, figsize=(15, 15))
ax[0].imshow(img, cmap='gray'), ax[0].axis('off'), ax[0].set_title('Original Image ')
ax[1].imshow(img_pred_1, cmap='gray'), ax[1].axis('off'), ax[1].set_title('1st Predicted Image')
ax[2].imshow(img_pred_2, cmap='gray'), ax[2].axis('off'), ax[2].set_title('2nd Predicted Image')
# Out:
# (<matplotlib.image.AxesImage at 0x1c4a200f748>,
#  (-0.5, 511.5, 511.5, -0.5),
#  Text(0.5, 1.0, 'Original Image '))
# (<matplotlib.image.AxesImage at 0x1c4a1a150c8>,
#  (-0.5, 495.5, 495.5, -0.5),
#  Text(0.5, 1.0, '1st Predicted Image'))
# (<matplotlib.image.AxesImage at 0x1c4a2088a88>,
#  (-0.5, 495.5, 495.5, -0.5),
#  Text(0.5, 1.0, '2nd Predicted Image'))
